# %% [markdown]
# # Astro 9

# %% [markdown]
# # Lecture 8: Intro to Pandas Continued

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Let's Look at some Plotting with Pandas
#
# ### Plotting a dataset

# %%
df = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

df = df.cumsum() #return a cumulative sum over the dataframe

df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
# 2000-01-01     1.443215
# 2000-01-02     2.566586
# 2000-01-03     3.752866
# 2000-01-04     3.576616
# 2000-01-05     4.531576
#                 ...
# 2002-09-22    40.380914
# 2002-09-23    40.232461
# 2002-09-24    40.032401
# 2002-09-25    39.641241
# 2002-09-26    39.316964
# Freq: D, Length: 1000, dtype: float64

# %% [markdown]
# ### Plotting 4 datasets at once

# %%
df2 = pd.DataFrame(np.random.randn(1000, 4), index=df.index, columns=list("ABCD"))
print(np.mean(df2.A))
df2 = df2.cumsum()

plt.figure()
df2.plot()
# Out:
# -0.044597933083742956
# <Axes: >

# %%
df2 = df.iloc[::5]
df2
# Out:
# 2000-01-01     1.443215
# 2000-01-06     3.962781
# 2000-01-11     3.790446
# 2000-01-16     3.005980
# 2000-01-21     1.076151
#                 ...
# 2002-09-02    37.910986
# 2002-09-07    41.808494
# 2002-09-12    41.151240
# 2002-09-17    37.752524
# 2002-09-22    40.380914
# Freq: 5D, Length: 200, dtype: float64

# %% [markdown]
# ### Scatter Plot

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=["a", "b", "c", "d"])
plt.figure()
df.plot.scatter(x="a", y="b");
#df.plot.scatter(x="c", y="d");

# %%
df
# Out:
#            a         b         c         d
# 0   0.438236  0.743058  0.961959  0.629726
# 1   0.332444  0.256858  0.916484  0.841039
# 2   0.018721  0.192736  0.307776  0.959844
# 3   0.635718  0.880503  0.935642  0.080925
# 4   0.641743  0.077548  0.165533  0.070973
# 5   0.868544  0.305159  0.955195  0.596443
# 6   0.525487  0.922401  0.218758  0.359132
# 7   0.438035  0.700161  0.472020  0.751570
# 8   0.291932  0.841410  0.239831  0.242542
# 9   0.607232  0.751999  0.168227  0.470957
# 10  0.227510  0.209212  0.955883  0.264704
# 11  0.796350  0.481665  0.934263  0.033822
# 12  0.211650  0.647910  0.506246  0.669827
# 13  0.936692  0.246821  0.192919  0.605761
# 14  0.684489  0.574435  0.989051  0.913146
# 15  0.020163  0.777056  0.638413  0.502284
# 16  0.004472  0.277222  0.198848  0.009013
# 17  0.079814  0.322557  0.951650  0.849769
# 18  0.448967  0.446656  0.918585  0.402036
# 19  0.204365  0.427389  0.123208  0.410143
# 20  0.032697  0.526256  0.807722  0.143300
# 21  0.490914  0.664484  0.901341  0.033809
# 22  0.216447  0.846508  0.835074  0.443454
# 23  0.142617  0.859338  0.307710  0.281818
# 24  0.173349  0.956131  0.741386  0.267546
# 25  0.897409  0.815948  0.208370  0.921315
# 26  0.684086  0.144410  0.904379  0.431729
# 27  0.800120  0.793259  0.344707  0.338099
# 28  0.319948  0.831843  0.286366  0.323877
# 29  0.251760  0.208317  0.357019  0.221811
# 30  0.123099  0.988735  0.526261  0.099021
# 31  0.821601  0.985018  0.424993  0.543458
# 32  0.810478  0.621302  0.918936  0.192848
# 33  0.135948  0.958769  0.898006  0.354667
# 34  0.717685  0.082235  0.615934  0.750805
# 35  0.811185  0.403182  0.241047  0.189513
# 36  0.669047  0.218120  0.044666  0.474026
# 37  0.261465  0.833683  0.854179  0.762067
# 38  0.004331  0.044723  0.799324  0.293560
# 39  0.169969  0.083934  0.785984  0.050283
# 40  0.569432  0.189075  0.936561  0.321024
# 41  0.852690  0.005382  0.670027  0.741822
# 42  0.608177  0.156490  0.151018  0.414497
# 43  0.393554  0.275718  0.933506  0.380502
# 44  0.240334  0.326614  0.705631  0.991018
# 45  0.760406  0.484608  0.684318  0.092899
# 46  0.408008  0.489799  0.886956  0.516922
# 47  0.292368  0.764498  0.600552  0.162678
# 48  0.926564  0.006396  0.247691  0.777057
# 49  0.931022  0.443029  0.506241  0.675557

# %% [markdown]
# ### Bar Plot

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df2
# Out:
#           a         b         c         d
# 0  0.966063  0.888437  0.233440  0.795136
# 1  0.647573  0.589980  0.238201  0.213780
# 2  0.663966  0.239710  0.531289  0.633082
# 3  0.842956  0.790372  0.939532  0.830041
# 4  0.327994  0.498080  0.999061  0.323420
# 5  0.595545  0.479944  0.598553  0.632791
# 6  0.639193  0.562011  0.209251  0.722503
# 7  0.080605  0.387745  0.162374  0.282076
# 8  0.899950  0.718615  0.698690  0.572513
# 9  0.532321  0.272042  0.523316  0.982789

# %% [markdown]
# ### Histograms

# %%
df4 = pd.DataFrame(
    {
        "a": np.random.randn(1000) + 1,
        "b": np.random.randn(1000),
        "c": np.random.randn(1000) - 1,
    },
    columns=["a", "b", "c"],
)


plt.figure();

df4.plot.hist(alpha=0.5);

# %%
plt.figure();

df4.plot.hist(stacked=True, bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df4
# Out:
#             a         b         c
# 0    1.093153  0.212055 -0.702712
# 1    1.293750 -0.326607 -2.858095
# 2    0.516129 -0.529917  0.140984
# 3    0.055653 -0.803357  0.233226
# 4    0.195252  0.668984  0.809344
# ..        ...       ...       ...
# 995  0.603319  2.035570 -0.760266
# 996  1.041559 -0.883251 -0.457123
# 997  1.298693 -0.134584  0.452753
# 998  0.251881  0.673147 -1.307140
# 999  0.774384  0.137397 -1.447593
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Box Plots

# %%
df5 = pd.DataFrame(np.random.rand(10, 5), columns=["A", "B", "C", "D", "E"])

df5.plot.box();

# %%
df5
# Out:
#           A         B         C         D         E
# 0  0.154446  0.601174  0.644758  0.991506  0.415248
# 1  0.220586  0.667169  0.631154  0.223788  0.534143
# 2  0.932259  0.448870  0.165294  0.123408  0.696526
# 3  0.008741  0.571976  0.063522  0.946804  0.930120
# 4  0.892397  0.805726  0.462100  0.497149  0.686485
# 5  0.101687  0.481251  0.097694  0.807390  0.160416
# 6  0.119924  0.687179  0.704828  0.930312  0.020015
# 7  0.055004  0.133530  0.233902  0.976721  0.614736
# 8  0.307720  0.746848  0.928429  0.060926  0.361510
# 9  0.244956  0.000105  0.420711  0.942900  0.105343

# %% [markdown]
# ### Pie Chart

# %%
series = pd.Series(3 * np.random.rand(4), index=["a", "b", "c", "d"], name="series")

series.plot.pie(figsize=(4, 2));

# %%
series
# Out:
# a    0.764979
# b    0.767715
# c    0.475884
# d    1.426820
# Name: series, dtype: float64

# %% [markdown]
# ### 3 Variable Plot

# %%
#load in the data to be corrected
beamspot_vals = np.loadtxt("with-mirror-200kpart.txt", comments = "%")

# %%
#define the datapoints within a pandas dataframe
df = pd.DataFrame(beamspot_vals, columns=['x', 'y', 'z', 'Intensity']) 
#delete the z axis data
df = df.drop('z', axis = 'columns')

# %%
#display a plot of the data
df.plot.scatter(x='x', y='y', c='Intensity',cmap='viridis', figsize = (12,10))
plt.ylabel('Centimeters')
# Out:
# Text(0, 0.5, 'Centimeters')

# %% [markdown]
# ## New Example: Analyzing a Type-1a Supernova Lightcurve

# %%
data = np.loadtxt('type_1a.txt')
df = pd.DataFrame(data, columns=['HJD', 'V', '+/-'])
df
# Out:
#           HJD       V    +/-
# 0   53788.119  17.950  0.023
# 1   53788.128  17.972  0.022
# 2   53788.139  17.917  0.022
# 3   53788.147  18.010  0.023
# 4   53788.155  17.975  0.022
# 5   53788.164  17.921  0.022
# 6   53788.176  17.957  0.022
# 7   53788.184  17.941  0.022
# 8   53788.193  17.916  0.022
# 9   53789.130  17.801  0.028
# 10  53790.112  17.697  0.025
# 11  53790.129  17.645  0.024
# 12  53791.122  17.540  0.024
# 13  53791.135  17.561  0.024
# 14  53792.124  17.462  0.026
# 15  53792.137  17.506  0.027
# 16  53793.124  17.458  0.023
# 17  53793.138  17.425  0.023
# 18  53794.115  17.442  0.023
# 19  53796.117  17.524  0.027
# 20  53797.118  17.507  0.025
# 21  53798.150  17.539  0.034
# 22  53803.161  17.981  0.074
# 23  53803.174  17.983  0.082
# 24  53805.114  18.167  0.105
# 25  53807.111  18.513  0.133

# %%
plt.title('Magnitude over Time of a Supernova')
plt.plot(df.HJD, df.V, '.')
plt.xlabel('Heliocentric Julien Day')
plt.ylabel('Apparent Magnitude')
# Out:
# Text(0, 0.5, 'Apparent Magnitude')

# %%
plt.title('Magnitude over Time of a Supernova')
plt.plot(df.HJD, -df.V, '.')
plt.xlabel('Heliocentric Julien Day')
plt.ylabel('Apparent Magnitude (Inverted)')
# Out:
# Text(0, 0.5, 'Apparent Magnitude (Inverted)')

# %%
print(np.min(df.V))
# Out:
# 17.425

# %%
def galactic_distance(m):
    M = -19.5 #this is the absolute magnitude of a type 1-a supernova
    d = 10**(5 + m - M)
    return d

print(galactic_distance(17.425), 'Parsecs')
# Out:
# 8.413951416451895e+41 Parsecs

# %%
# 1 Parsec = 3.26156 light years

dist = galactic_distance(17.425)*3.26156
print(dist, 'Light Years')
# Out:
# 2.744260738184284e+42 Light Years

# %% [markdown]
# ## Is this the actual distance?

# %% [markdown]
# What did we do wrong here?
